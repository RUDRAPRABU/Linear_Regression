# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('hiring.csv')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.isna().sum()
# Out:
# experience                    2
# test_score(out of 10)         1
# interview_score(out of 10)    0
# salary($)                     0
# dtype: int64

# %%
df['experience'] = df['experience'].fillna('zero')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
pip install word2number
# Out:
# Requirement already satisfied: word2number in c:\users\rudra prabu s\anaconda3\lib\site-packages (1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from word2number import w2n
df['experience'] = df['experience'].apply(w2n.word_to_num)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000

# %%
mean_testscore = df['test_score(out of 10)'].mean()
df.fillna(value = mean_testscore,inplace=True)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0               8.000000                           9      50000
# 1           0               8.000000                           6      45000
# 2           5               6.000000                           7      60000
# 3           2              10.000000                          10      65000
# 4           7               9.000000                           6      70000
# 5           3               7.000000                          10      62000
# 6          10               7.857143                           7      72000
# 7          11               7.000000                           8      80000

# %%
df.corr()
# Out:
#                             experience  test_score(out of 10)  \
# experience                    1.000000              -0.241897
# test_score(out of 10)        -0.241897               1.000000
# interview_score(out of 10)   -0.290480               0.139710
# salary($)                     0.908017              -0.002850
#
#                             interview_score(out of 10)  salary($)
# experience                                    -0.29048   0.908017
# test_score(out of 10)                          0.13971  -0.002850
# interview_score(out of 10)                     1.00000   0.037820
# salary($)                                      0.03782   1.000000

# %%
x=df.drop(columns=['salary($)'])
y=df['salary($)']

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[2,9,6],[12,10,10]])
# Out:
# array([53290.89255945, 92268.07227784])
